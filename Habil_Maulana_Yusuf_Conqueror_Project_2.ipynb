# %% [markdown]
# <a href="https://colab.research.google.com/github/habilmaulana/Mini-Project/blob/main/Habil_Maulana_Yusuf_Conqueror_Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Customer Segmentation

# %% [markdown]
# ## Background

# %% [markdown]
# This dataset contains all purchases made for an online retail company based in the UK during an eight month period. We could use cluster analysis combined with RFM analysis to do a customer segmentation.

# %% [markdown]
# ## Prepare and Explore the Data

# %% [markdown]
# For this experiment, we will use [this](https://www.kaggle.com/vijayuv/onlineretail) data from Kaggle platform.

# %%
# Package imports
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

pd.set_option('display.max_rows', None)

# %%
# Load data
df = pd.read_excel('https://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# The data contains 541909 rows and 8 columns, each row represents each item in a purchasement. The columns are:
# * `InvoiceNo` - Invoice number, to identify each invoice
# * `StockCode` - Stock code, to identify each item in the inventory
# * `Description` - Item's description
# * `Quantity` - Number of purchased item in each invoice
# * `InvoiceDate` - Date of purchasement
# * `UnitPrice` - Item's price per unit
# * `CustomerID` - Customer's identification number
# * `Country` - Customer's country of origin

# %% [markdown]
# Since we want to segment our customers, we have to make sure that `CustomerID` is not null.

# %%
# Check missing value
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# We could see that there is missing value in `Description`  and `CustomerID` columns. We could remove those missing values.

# %%
# Remove missing value
df = df[df["CustomerID"].notna()]

df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
df.shape
# Out:
# (406829, 8)

# %% [markdown]
# Then we could do some descriptive statistic.

# %%
# Simple descriptive statistic
df[["Quantity", "UnitPrice"]].describe()
# Out:
#             Quantity      UnitPrice
# count  406829.000000  406829.000000
# mean       12.061303       3.460471
# std       248.693370      69.315162
# min    -80995.000000       0.000000
# 25%         2.000000       1.250000
# 50%         5.000000       1.950000
# 75%        12.000000       3.750000
# max     80995.000000   38970.000000

# %% [markdown]
# Wait, hold on. How come the quantity is a negative number and the unit price is zero? Let's check it.

# %%
# Check anomaly data (Ada berapa data yg kurang dari 0 untuk quantity dan sama dengan 0 untuk price)
quantity_zero = len(df[df["Quantity"] <= 0])
perc_quantity_zero = (len(df[df["Quantity"] <= 0]) / len(df)) * 100
unit_price_zero = len(df[df["UnitPrice"] == 0])
perc_unit_price_zero = (len(df[df["UnitPrice"] == 0]) / len(df)) * 100

print("The Dataset consist of", str(quantity_zero), "rows of data with quantity less or equal then zero")
print("About {:.2f}% of total data".format(perc_quantity_zero))
print("The Dataset consist of", str(unit_price_zero), "rows of data with quantity less or equal then zero")
print("About {:.2f}% of total data".format(perc_unit_price_zero))
# Out:
# The Dataset consist of 8905 rows of data with quantity less or equal then zero
# About 2.19% of total data
# The Dataset consist of 40 rows of data with quantity less or equal then zero
# About 0.01% of total data

# %% [markdown]
# Then just remove those anomaly data

# %%
# Remove anomaly / outliers
df = df[(df["Quantity"] > 0) & (df["UnitPrice"] > 0)]
df[["Quantity", "UnitPrice"]].describe()
# Out:
#             Quantity      UnitPrice
# count  397884.000000  397884.000000
# mean       12.988238       3.116488
# std       179.331775      22.097877
# min         1.000000       0.001000
# 25%         2.000000       1.250000
# 50%         6.000000       1.950000
# 75%        12.000000       3.750000
# max     80995.000000    8142.750000

# %%
df[df["Quantity"] == 80995]
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 540421    581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 540421 2011-12-09 09:15:00       2.08     16446.0  United Kingdom

# %% [markdown]
# Now we're good to go. Lets do some data exploration!

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
# Check unique value
df[["InvoiceNo", "StockCode", "CustomerID", "Country"]].nunique()
# Out:
# InvoiceNo     18532
# StockCode      3665
# CustomerID     4338
# Country          37
# dtype: int64

# %% [markdown]
# There are 18532 purchasements, 3665 unique item purchased, from 4338 customers that came from 37 countries.

# %% [markdown]
# As we seen above, there are 37 countries of customer's origin. Since the retail company is based in the UK, we could simplified the country as UK or Non UK

# %%
# Simplify country origin (Pie chart untuk melihat komposisi negara)
df['Country_isUK'] = np.where(df['Country']=='United Kingdom', 'UK', 'Non UK')

customers_origin = df.groupby(['Country_isUK']).size()

plt.title('Customers Origin Proportion')
plt.pie(customers_origin, labels=customers_origin.index, autopct=lambda p: f'{p:.2f}%')
plt.show();

# %% [markdown]
# Based on the piechart, we could see that mostly our customers are from the UK.

# %% [markdown]
# Next, we could analyze the trend of purchasement. First, lets create `TotalAmount` column (`Quantity` * `UnitPrice`). Then, we could transform the `InvoiceDate` data type from string to date.

# %%
# Create new features and cast date column
df['TotalAmount'] = df['Quantity'] * df['UnitPrice']
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country Country_isUK  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom           UK
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom           UK
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom           UK
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom           UK
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom           UK
#
#    TotalAmount
# 0        15.30
# 1        20.34
# 2        22.00
# 3        20.34
# 4        20.34

# %% [markdown]
# Then plot the trendline.

# %%
import matplotlib.dates as mdates

# %%
# Plot weekly trend
weekly_purchasements = df.copy()
weekly_purchasements = weekly_purchasements.groupby(
    by=pd.Grouper(key="InvoiceDate", freq="1W"))["TotalAmount"].sum()

plt.figure(figsize=(20, 7))
plt.title('Weekly Purchasement Trend')
ax = sns.lineplot(
    x=weekly_purchasements.index,
    y=weekly_purchasements,
    marker='*',
    markersize=10,
    markerfacecolor='red'
)
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
plt.grid()
plt.show();

# %%
# Plot monthly trend
monthly_purchasements = df.copy()
monthly_purchasements = monthly_purchasements.groupby(by = pd.Grouper(key="InvoiceDate", freq="1M"))["TotalAmount"].sum()

plt.figure(figsize=(20, 7))
plt.title('Monthly Purchasement Trend')
ax = sns.lineplot(
    x=monthly_purchasements.index,
    y=monthly_purchasements,
    marker='*',
    markersize=10,
    markerfacecolor='red'
)
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))
plt.grid()
plt.show();
# Out:
# <ipython-input-17-5b277a02505f>:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_purchasements = monthly_purchasements.groupby(by = pd.Grouper(key="InvoiceDate", freq="1M"))["TotalAmount"].sum()

# %% [markdown]
# Based on the picture above, it can be seen that there was an increase in total purchases at the end of the year.

# %% [markdown]
# ## RFM

# %% [markdown]
# In this project, we would segment the customers using customer's demography and purchasement behavior. To explain the customer's demography, we could use `Country` column while to explain the customer's purchasement behavior we have to transform our data first to get those information. We could use RFM analysis to get those information.

# %% [markdown]
# ### Recency

# %% [markdown]
# To measure customer's recency, we could substract the latest transaction date in the data with each customer's latest transaction.

# %%
# Get customer's recency
recency = df.groupby(["CustomerID"])["InvoiceDate"].max()
recency = max(recency) - recency
recency = recency.dt.days
recency = recency.rename("Recency")

recency.head()
# Out:
# CustomerID
# 12346.0    325
# 12347.0      1
# 12348.0     74
# 12349.0     18
# 12350.0    309
# Name: Recency, dtype: int64

# %%
# Recency histogram plot
plt.title("Customer Recency Distribution")
sns.histplot(recency)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Frequency

# %% [markdown]
# To measure customer's frequency, we could count customer's invoice.

# %%
# Count frequency
frequency = df.groupby(["CustomerID"])["InvoiceNo"].count()
frequency = frequency.rename("Frequency")

frequency.head()
# Out:
# CustomerID
# 12346.0      1
# 12347.0    182
# 12348.0     31
# 12349.0     73
# 12350.0     17
# Name: Frequency, dtype: int64

# %%
# Frequency histogram plot
plt.title("Customer Frequency Distribution")
sns.histplot(frequency)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
frequency.sort_values(ascending=False).head()
# Out:
# CustomerID
# 17841.0    7847
# 14911.0    5675
# 14096.0    5111
# 12748.0    4595
# 14606.0    2700
# Name: Frequency, dtype: int64

# %% [markdown]
# ### Monetary

# %% [markdown]
# To measure customer's monetary, we could sum the customer's total purchasements.

# %%
# Sum the money spent
monetary = df.groupby(["CustomerID"])["TotalAmount"].sum()
monetary = monetary.rename("Monetary")

monetary.head()
# Out:
# CustomerID
# 12346.0    77183.60
# 12347.0     4310.00
# 12348.0     1797.24
# 12349.0     1757.55
# 12350.0      334.40
# Name: Monetary, dtype: float64

# %%
# Monetary histogram plot
plt.title("Customer Monetary Distribution")
sns.histplot(monetary)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
monetary.sort_values(ascending=False).head()
# Out:
# CustomerID
# 14646.0    280206.02
# 18102.0    259657.30
# 17450.0    194550.79
# 16446.0    168472.50
# 14911.0    143825.06
# Name: Monetary, dtype: float64

# %% [markdown]
# ### Merge the Data

# %% [markdown]
# The data could be separated into two dataframes. The first dataframe (log transformed data) supposed to be used when modeling and the second one (without log transformation) could be used when visualize the result.

# %%
# Get customer's country of origin
country = (
    df.groupby(['CustomerID', 'Country_isUK'])
    .size()
    .reset_index()
    .drop(0, axis=1)
)#chaining method

country.head()
# Out:
#    CustomerID Country_isUK
# 0     12346.0           UK
# 1     12347.0       Non UK
# 2     12348.0       Non UK
# 3     12349.0       Non UK
# 4     12350.0       Non UK

# %%
# Merge the data
df_new = country.merge(recency, on= "CustomerID")\
                .merge(frequency, on= "CustomerID")\
                .merge(monetary, on= "CustomerID")

# Set CustomerID as index
df_new = df_new.set_index("CustomerID")
df_new.head()
# Out:
#            Country_isUK  Recency  Frequency  Monetary
# CustomerID
# 12346.0              UK      325          1  77183.60
# 12347.0          Non UK        1        182   4310.00
# 12348.0          Non UK       74         31   1797.24
# 12349.0          Non UK       18         73   1757.55
# 12350.0          Non UK      309         17    334.40

# %% [markdown]
# ### One Hot Encoding

# %% [markdown]
# Since our model could just accept the numeric value, we have to recode the non numeric column.

# %%
# Recode the non numeric variable
df_new = pd.get_dummies(df_new, columns=["Country_isUK"], drop_first=True, dtype=float)
df_new = df_new.rename(columns={"Country_isUK_UK": "Country_UK"})

df_new.head()
# Out:
#             Recency  Frequency  Monetary  Country_UK
# CustomerID
# 12346.0         325          1  77183.60         1.0
# 12347.0           1        182   4310.00         0.0
# 12348.0          74         31   1797.24         0.0
# 12349.0          18         73   1757.55         0.0
# 12350.0         309         17    334.40         0.0

# %% [markdown]
# ### Scaling

# %%
sns.boxplot(data = df_new)
plt.show()

# %% [markdown]
# As we could see, there are variation of range in each column. We have to standardize it first.

# %%
# Scale the data

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_new)

df_scaled = pd.DataFrame(
    df_scaled,
    columns=df_new.columns,
    index=df_new.index
)

df_scaled.head()
# Out:
#              Recency  Frequency  Monetary  Country_UK
# CustomerID
# 12346.0     2.334574  -0.396578  8.358668    0.326547
# 12347.0    -0.905340   0.394649  0.250966   -3.062350
# 12348.0    -0.175360  -0.265435 -0.028596   -3.062350
# 12349.0    -0.735345  -0.081836 -0.033012   -3.062350
# 12350.0     2.174578  -0.326635 -0.191347   -3.062350

# %%
# Plot scaled data
sns.boxplot(data = df_scaled)
plt.grid()
plt.show()

# %% [markdown]
# ## Modeling

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Modeling
possible_k = [2, 3, 4, 5, 6, 7, 8, 9, 10]
silhouette = []

for k in possible_k:
    kmeans = KMeans(n_clusters=k, random_state=42).fit(df_scaled)
    silhouette.append(silhouette_score(X=df_scaled, labels=kmeans.labels_))

# %%
# Plot the score
plt.figure(figsize=(12, 7))
sns.lineplot(
    x=possible_k,
    y=silhouette,
    marker='*',
    markersize=10,
    markerfacecolor='red'
)
plt.xlabel('Values of K')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score Method')
plt.grid()
plt.show();

# %% [markdown]
# Using silhouette score, the best K is 2

# %%
#Pairplot
kmeans = KMeans(n_clusters=2,random_state=42).fit(df_scaled)

df_result_kmeans = df_new.copy()
df_result_kmeans['cluster'] = kmeans.labels_

sns.pairplot(
    data=df_result_kmeans,
    hue='cluster',
    diag_kind='None',
    palette='tab10'
)

plt.show();

# %%
# Quantile function
def q25(x):
    return x.quantile(0.25)

def q75(x):
    return x.quantile(0.75)

# Simple descriptive statistic
(
    df_result_kmeans
    .drop("Country_UK", axis = 1)
    .groupby('cluster')
    .aggregate(['mean', 'std', 'min', q25, 'median', q75, 'max'])
    .transpose()
)
# Out:
# cluster                      0              1
# Recency   mean       91.800462       3.692308
#           std       100.047598       6.459936
#           min         0.000000       0.000000
#           q25        17.000000       0.000000
#           median     50.000000       1.000000
#           q75       142.000000       3.000000
#           max       373.000000      23.000000
# Frequency mean       84.285549    2565.307692
#           std       131.516667    2456.928617
#           min         1.000000       3.000000
#           q25        17.000000     714.000000
#           median     41.000000    1818.000000
#           q75        99.000000    4595.000000
#           max      2700.000000    7847.000000
# Monetary  mean     1681.357196  126118.310000
#           std      4074.628323   80607.677360
#           min         3.750000   33719.730000
#           q25       306.940000   60767.900000
#           median    669.110000  117379.630000
#           q75      1651.030000  168472.500000
#           max     81024.840000  280206.020000

# %%
df_result_kmeans.groupby(["cluster", "Country_UK"])["Recency"].count()
# Out:
# cluster  Country_UK
# 0        0.0            414
#          1.0           3911
# 1        0.0              4
#          1.0              9
# Name: Recency, dtype: int64

# %%
df_result_kmeans.groupby(["cluster", "Country_UK"])["Frequency"].count()
# Out:
# cluster  Country_UK
# 0        0.0            414
#          1.0           3911
# 1        0.0              4
#          1.0              9
# Name: Frequency, dtype: int64

# %% [markdown]
# That's it! The customer's behavior really segmented by their country of origin.
#
# What if we separate the customer by its country of origin before doing cluster analysis?

# %% [markdown]
# # Question

# %% [markdown]
# 1. (30 point) Lakukan EDA lebih mendalam dari data yang tersedia. Misalnya: a) Siapa top 5 customer dengan pembelian terbanyak? b) Kapan waktu pembelian dengan jumlah customer terbanyak? (Misal hari apa, jam berapa, bulan apa, minggu ke berapa, dst). EDA juga bisa dilakukan menggunakan business question lain.
# 2. (30 point) Apa karakteristik/ciri utama dari masing-masing cluster? Apa promo yang kira-kira cocok untuk diberikan ke masing-masing cluster?
# 3. (40 point) Bagaimana jika segmentation difokuskan untuk customer di luar UK? Apakah terdapat insight yang menarik? Apa karakteristik utama dari cluster-cluster non UK?

# %% [markdown]
# #Jawaban Question 1

# %% [markdown]
# ## a. 5 Customer dengan Pembelian Terbanyak

# %%
top_customers = df.groupby("CustomerID")["Quantity"].sum().nlargest(5).reset_index()
print("Top 5 Customers:")
print(top_customers)
# Out:
# Top 5 Customers:
#    CustomerID  Quantity
# 0     14646.0    196915
# 1     16446.0     80997
# 2     14911.0     80265
# 3     12415.0     77374
# 4     12346.0     74215

# %% [markdown]
# ## b. Waktu Pembelian dengan Jumlah Customer Terbanyak

# %%
df["Day"] = df["InvoiceDate"].dt.day_name()
df["Hour"] = df["InvoiceDate"].dt.hour
df["Month"] = df["InvoiceDate"].dt.month
df["Week"] = df["InvoiceDate"].dt.isocalendar().week

# %%
# Visualisasi Berdasarkan Bulan
df_monthly = df.groupby("Month")["CustomerID"].nunique().reset_index()
plt.figure(figsize=(12, 6))
sns.barplot(x="Month", y="CustomerID", data=df_monthly)
plt.title("Distribusi Waktu berdasarkan Bulan")
plt.xlabel("Bulan")
plt.ylabel("Jumlah Customer")
plt.show()

# %%
# Visualisasi Minggu
df_weekly = df.groupby("Week")["CustomerID"].nunique().reset_index()
plt.figure(figsize=(12, 6))
sns.barplot(x="Week", y="CustomerID", data=df_weekly)
plt.title("Distribusi Waktu Pembelian berdasarkan Minggu")
plt.xlabel("Minggu ke")
plt.ylabel("Jumlah Customer")
plt.show()

# %%
# Visualisasi per Hari
plt.figure(figsize=(12, 6))
sns.countplot(x="Day", data=df, order=["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"])
plt.title("Distribusi Waktu Pembelian berdasarkan Hari")
plt.show()

# %%
# Visualisasi per Jam
plt.figure(figsize=(12, 6))
sns.countplot(x="Hour", data=df)
plt.title("Distribusi Waktu Pembelian berdasarkan Jam")
plt.show()

# %% [markdown]
# Setelah menganalisis keempat grafik berdasarkan bulan, minggu, hari, dan jam, berikut adalah insight yang bisa diambil:
# 1. Berdasarkan Bulan
#   * Terjadi peningkatan jumlah customer dari bulan September - November, dengan puncak kenaikan terjadi pada bulan November. Ini bisa terjadi karena ada beberapa event seperti Black Friday dan persiapan libur akhir tahun.
#   * Jumlah customer stabil di awal tahun, lalu meningkat signifikan di akhir tahun.
#   * Terjadi penurunan setelah bulan Desember, mungkin karena pelanggan sudah banyak berbelanja sebelumnya dan mengurangi konsumsi setelah liburan.
#
# 2. Berdasarkan Minggu
#   * Lonjakan besar terjadi di minggu ke-48. Bisa terjadi karena event seperti Black Fiday, Cyber Monday, dan Persiapan libur akhir tahun.
#   * Peningkatan pembelian mulai terjadi dari minggu ke-40 hingga puncaknya di minggu ke-48.
#   * Penurunan tajam setelah minggu ke-49, karena sudah memasuki akhir tahun dan pelanggan mengurangi belanja.
#
# 3. Berdasarkan Hari
#   * Pembelian cukup konsisten dari Senin hingga Rabu, lalu puncak pembelian terjadi pada hari Kamis.
#   * Terjadi penurunan pada hari Jum'at dan Sabtu, sebelum naik lagi pada hari Minggu.
#
# 4. Berdasarkan Jam
#   * Pembelian mencapai puncak terjadi pukul 12:00 (siang). Menunjukkan bahwa pelanggan lebih aktif berbelanja menjelang waktu makan siang.
#   * Setelah pukul 12:00, masih terdapat aktivitas belanja yang cukup tinggi hingga pukul 14:00 sebelum akhirnya menurun.
#   * Transaksi paling rendah terjadi di pagi hari (06:00 - 07:00) dan sore hingga malam hari (17:00 - 20:00).
#
# 5. Strtaegi Optimalisasi Penjualan
#   * Optimasi promosi besar pada bulan November & minggu ke-47 hingga minggu ke-49.
#   * menawarkan program loyalitas setelah bulan Desember untuk mempertahankan pelanggan (mencegah churning).
#   * Maksimalkan promo di jam 11:00-13:00 dan di hari kerja.
#   * Membuat strategi weekend sale agar penjualan tetap stabil di akhir pekan.

# %% [markdown]
# ## c. 5 Produk dengan Penjualan Tertinggi

# %%
top_products = df.groupby(["StockCode", "Description"])["Quantity"].sum().nlargest(5).reset_index()
top_products.columns = ["StockCode", "Description", "Total Quantity"]
print("Top 5 Produk dengan Penjualan Terbanyak:")
print(top_products)
# Out:
# Top 5 Produk dengan Penjualan Terbanyak:
#   StockCode                         Description  Total Quantity
# 0     23843         PAPER CRAFT , LITTLE BIRDIE           80995
# 1     23166      MEDIUM CERAMIC TOP STORAGE JAR           77916
# 2     84077   WORLD WAR 2 GLIDERS ASSTD DESIGNS           54415
# 3    85099B             JUMBO BAG RED RETROSPOT           46181
# 4    85123A  WHITE HANGING HEART T-LIGHT HOLDER           36725

# %% [markdown]
# #Jawaban Question 2

# %%
# Karakteristik Cluster (3 Cluster)
#Pairplot
kmeans = KMeans(n_clusters=3,random_state=42).fit(df_scaled)

df_result_kmeans = df_new.copy()
df_result_kmeans['cluster'] = kmeans.labels_

sns.pairplot(
    data=df_result_kmeans,
    hue='cluster',
    diag_kind='None',
    palette='tab10'
)

plt.show();

# %%
# Quantile function
def q25(x):
    return x.quantile(0.25)

def q75(x):
    return x.quantile(0.75)

# Simple descriptive statistic
(
    df_result_kmeans
    .drop("Country_UK", axis = 1)
    .groupby('cluster')
    .aggregate(['mean', 'std', 'min', q25, 'median', q75, 'max'])
    .transpose()
)
# Out:
# cluster                       0             1              2
# Recency   mean        39.530598    243.142714      94.571770
#           std         34.796185     67.322624     104.485451
#           min          0.000000    135.000000       0.000000
#           q25         11.000000    185.000000      18.000000
#           median      29.000000    238.000000      51.000000
#           q75         61.000000    294.000000     134.500000
#           max        155.000000    373.000000     373.000000
# Frequency mean       111.691966     27.760804     104.217703
#           std        247.879197     32.138112     313.632715
#           min          1.000000      1.000000       1.000000
#           q25         24.000000      8.500000      22.000000
#           median      57.000000     18.000000      45.000000
#           q75        124.000000     33.000000     102.500000
#           max       7847.000000    297.000000    5675.000000
# Monetary  mean      2290.607659    611.421257    3834.967344
#           std       8426.400177   3127.899451   17626.226186
#           min          6.200000      3.750000      51.560000
#           q25        396.480000    163.250000     460.522500
#           median     903.900000    305.780000    1031.995000
#           q75       2031.780000    511.250000    2705.637500
#           max     259657.300000  77183.600000  280206.020000

# %%
df_result_kmeans.groupby(["cluster", "Country_UK"])["Recency"].count()
# Out:
# cluster  Country_UK
# 0        1.0           2925
# 1        1.0            995
# 2        0.0            418
# Name: Recency, dtype: int64

# %%
df_result_kmeans.groupby(["cluster", "Country_UK"])["Frequency"].count()
# Out:
# cluster  Country_UK
# 0        1.0           2925
# 1        1.0            995
# 2        0.0            418
# Name: Frequency, dtype: int64

# %%
df_result_kmeans.groupby(["cluster", "Country_UK"])["Monetary"].count()
# Out:
# cluster  Country_UK
# 0        1.0           2925
# 1        1.0            995
# 2        0.0            418
# Name: Monetary, dtype: int64

# %% [markdown]
# Berdasarkan pair plot, statistik deskriptif, dan jumlah pelanggan berdasarkan *Country*, bisa disimpulkan karakteristik dari tiga cluster sebagai berikut:
# 1. Cluster 0
#   * Recency (mean = 39,5) -> sering melakukan transaksi dalam beberapa minggu terakhir.
#   * Freuency (mean = 111,6) -> sering berbelanja, beberapa pelanggan bisa sangat aktif (max = 7.847 transaksi).
#   * Monetary (mean = 2.290,6) -> pengeluaran cukup besar, meskipun terdapat variasi.
#   * Mayoritas berasal dari UK (2.295 pelanggan) dan tidak ada dari luar UK.
#
# 2. Cluster 1
#   * Recency (mean = 243,1) -> sudah lama tidak belanja, bahkan bberapa pelanggan berbelanja lebih dari 300 hari yang lalu.
#   * Freuency (mean = 27,8) -> tidak terlalu sering melakukan transaksi.
#   * Monetary (mean = 611,4) -> dibandingkan cluster lain, pengeluaran cluster ini jauh lebih kecil.
#   * Mayoritas berasal dari UK (995 pelanggan).
#
# 3. Cluster 2
#   * Recency (mean = 94,5) -> tidak seaktif cluster 0, tetapi lebih aktif dibandingkan cluster 1.
#   * Freuency (mean = 10,2) -> masih sering melakukan transaksi, mesipun tidak sebanyak cluster 0.
#   * Monetary (mean = 3.834,9) -> pengeluaran paling besar dari cluster lain (max = 80.206).
#   * Mayoritas berasal dari luar UK (418 pelanggan) dan tidak ada dari UK.

# %% [markdown]
# **Kesimpulan & Strategi yang Bisa Diterapkan**
# ![Screenshot 2025-03-16 094204.png](data:image/png;base64,...)

# %% [markdown]
# #Jawaban Question 3

# %%
df["Country_isUK"].unique()
# Out:
# array(['UK', 'Non UK'], dtype=object)

# %%
df["Country_isUK"].value_counts()
# Out:
# Country_isUK
# UK        354321
# Non UK     43563
# Name: count, dtype: int64

# %%
df_non_uk = df_new[df_new['Country_UK'] == 0].copy()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_scaled_non_uk = scaler.fit_transform(df_non_uk.drop(columns=['Country_UK']))

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

inertia = []
K_range = range(1, 11)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df_scaled_non_uk)
    inertia.append(kmeans.inertia_)

plt.plot(K_range, inertia, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal K')
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=42)  # Gantilah 3 dengan hasil dari Elbow Method
df_non_uk['cluster'] = kmeans.fit_predict(df_scaled_non_uk)

# %%
import seaborn as sns

sns.pairplot(data=df_non_uk, hue='cluster', diag_kind='kde', palette='tab10')
plt.show()

# %% [markdown]
# Berdasarkan hasil output dari analisis karakteristik utama dari masing-masing cluster non UK, berikut adalah beberapa kesimpulan yang dapat diambil:
#
# 1. Cluster 0
#   * Recency rendah -> baru saja bertransaski.
#   * Frequency rendah -> jarang melakukan pembelian.
#   * Monetary rendah -> total nilai transaksi kecil.
#   * Memiliki jumlah pelanggan terbanyak.
#   * Peluang peningkatan transaksi:
#     * Memberikan dikon atau loyalty program agar pelanggan kembali melakukan transaksi.
#     * Email marketing dengan rekomendasi produk yang sesuai dengan riwayat pembelian.
#     * Menawarkan produk tambahan yang relevan berdasarkan pembelian.
#     * Melakukan bundling.
#
# 2. Cluster 1
#   * Recency tinggi -> sudah lama tidak bertransaski.
#   * Frequency sangat tinggi -> pelanggan yang sangat aktif saat masih berbelanja.
#   * Monetary sangat tinggi -> melakukan pembelian dalam jumlah yang sangat besar.
#   * Hanya ada sedikit pelanggan di cluster ini.
#   * Peluang reaktivasi pelanggan:
#     * Mengirimkan email dengan diskon khusus atau penawaran eksklusif.
#     * Mendapatkan akses eksklusif ke diskon besar sebelum pelanggan reguler.
#     * Mengajak untuk merekomendasikan brand ke pelanggan lain dengan intensif menarik.
#
# 3. Cluster 2
#   * Recency bervariasi -> ada yang baru bertransaski, ada juga yang sudah lama tidak bertransaksi.
#   * Frequency sedang -> melakukan pembelian lebih sering dibandingkan dengan Cluster 0.
#   * Monetary menengah -> nilai transaksi lebih tinggi dibanding Cluster 0, tetapi tidak terlalu tinggi juga.
#   * Peluang meningkatkan retensi dan loyalitas:
#     * Program membership untuk membuat pelanggan tetap loyal.
#     * Menawarkan produk yang lebih premium.
#     * Retargeting Ads di media sosial untuk mendorong pembelian ulang.
#
# **Kesimpulan (Strategi Utama)**
# 1. Cluster 0 (Low Engagement): Fokus kepada etensi dan peningkatan engagement.
# 2. Cluster 1 (High-Value Customers): Cegah churn dengan personalized offers dan reaktivasi.
# 3. Cluster 2 (Regular Customers): Buat pelanggan lebih loyal dengan rewards & upselling.
